# %%
import tensorflow as tf 
from tensorflow import keras
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Activation, ReLU
from tensorflow.keras.layers import BatchNormalization, Conv2DTranspose, Concatenate
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras import layers
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
import os

input_dir = "/gdrive/MyDrive/Colab Notebooks/victor/original images"
target_dir = "/gdrive/MyDrive/Colab Notebooks/victor/annotated images"

input_img_paths = sorted(
    [os.path.join(input_dir, fname)
     for fname in os.listdir(input_dir)
     if fname.endswith(".jpg")])
target_paths = sorted(
    [os.path.join(target_dir, fname)
     for fname in os.listdir(target_dir)
     if fname.endswith(".png") and not fname.startswith(".")])

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img, img_to_array
img_size = (256, 256)
num_imgs = len(input_img_paths)

random.Random(1337).shuffle(input_img_paths)
random.Random(1337).shuffle(target_paths)

def path_to_input_image(path):
    return img_to_array(load_img(path, target_size=img_size))

def path_to_target(path):
    img = img_to_array(
        load_img(path, target_size=img_size, color_mode="grayscale"))
    img = img.astype("uint8") - 1
    return img

input_imgs = np.zeros((num_imgs,) + img_size + (3,), dtype="float32")
targets = np.zeros((num_imgs,) + img_size + (1,), dtype="uint8")
for i in range(num_imgs):
    input_imgs[i] = path_to_input_image(input_img_paths[i])
    targets[i] = path_to_target(target_paths[i])

targets = targets*(1./255)

num_val_samples = 15
train_input_imgs = input_imgs[:-num_val_samples]
train_targets = targets[:-num_val_samples]
val_input_imgs = input_imgs[-num_val_samples:]
val_targets = targets[-num_val_samples:]

# %%
print(len(val_targets))
print(len(train_input_imgs))
original = keras.preprocessing.image.array_to_img(train_input_imgs[1])
display(original)
original = keras.preprocessing.image.array_to_img(train_targets[1])
display(original)
# Out:
# 15
# 145
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FC6B90C3690>
# <PIL.Image.Image image mode=L size=256x256 at 0x7FC6B90C3890>

# %%
def convolution_operation(entered_input, filters=64):
    # Taking first input and implementing the first conv block
    conv1 = Conv2D(filters, kernel_size = (3,3), padding = "same")(entered_input)
    batch_norm1 = BatchNormalization()(conv1)
    act1 = ReLU()(batch_norm1)
    
    # Taking first input and implementing the second conv block
    conv2 = Conv2D(filters, kernel_size = (3,3), padding = "same")(act1)
    batch_norm2 = BatchNormalization()(conv2)
    act2 = ReLU()(batch_norm2)
    return act2

def encoder(entered_input, filters=64):
    # Collect the start and end of each sub-block for normal pass and skip connections
    enc1 = convolution_operation(entered_input, filters)
    MaxPool1 = MaxPooling2D(strides = (2,2))(enc1)
    return enc1, MaxPool1

def decoder(entered_input, skip, filters=64):
    # Upsampling and concatenating the essential features
    Upsample = Conv2DTranspose(filters, (2, 2), strides=2, padding="same")(entered_input)
    Connect_Skip = Concatenate()([Upsample, skip])
    out = convolution_operation(Connect_Skip, filters)
    return out

# %%
num_classes = 2

def U_Net(Image_Size):
    # Take the image size and shape
    input = Input(shape=img_size + (3,))
    input1 = layers.Rescaling(1./255)(input)

    # Construct the encoder blocks
    skip1, encoder_1 = encoder(input1, 64)
    skip2, encoder_2 = encoder(encoder_1, 64*2)
    skip3, encoder_3 = encoder(encoder_2, 64*4)
    skip4, encoder_4 = encoder(encoder_3, 64*8)
    
    # Preparing the next block
    conv_block = convolution_operation(encoder_4, 64*16)
    
    # Construct the decoder blocks
    decoder_1 = decoder(conv_block, skip4, 64*8)
    decoder_2 = decoder(decoder_1, skip3, 64*4)
    decoder_3 = decoder(decoder_2, skip2, 64*2)
    decoder_4 = decoder(decoder_3, skip1, 64)
    
    out = Conv2D(num_classes, 1, activation="sigmoid", padding="same")(decoder_4)
    model = Model(input1, out)
    return model

input_shape = img_size
model = U_Net(input_shape)

# %%
model.compile(optimizer="rmsprop", loss="sparse_categorical_crossentropy")
#model.compile(optimizer="Adam", loss="sparse_categorical_crossentropy")
#model.compile(optimizer=opt, loss="sparse_categorical_crossentropy")


callbacks = [
    keras.callbacks.ModelCheckpoint("/gdrive/MyDrive/Colab Notebooks/victor/unet2_trash2.keras",
                                    save_best_only=True)
]

history = model.fit(train_input_imgs, train_targets,
                    epochs=50,
                    callbacks=callbacks,
                    validation_data=(val_input_imgs, val_targets))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 30s 3s/step - loss: 0.8214 - val_loss: 22183214.0000
# Epoch 2/50
# 5/5 [==============================] - 5s 951ms/step - loss: 0.6367 - val_loss: 79576.3359
# Epoch 3/50
# 5/5 [==============================] - 5s 953ms/step - loss: 0.6072 - val_loss: 2118.6812
# Epoch 4/50
# 5/5 [==============================] - 4s 764ms/step - loss: 0.6018 - val_loss: 143486.5938
# Epoch 5/50
# 5/5 [==============================] - 5s 948ms/step - loss: 0.5932 - val_loss: 1453.7063
# Epoch 6/50
# 5/5 [==============================] - 4s 761ms/step - loss: 0.5770 - val_loss: 17417.3320
# Epoch 7/50
# 5/5 [==============================] - 4s 764ms/step - loss: 0.5546 - val_loss: 46686.6758
# Epoch 8/50
# 5/5 [==============================] - 5s 965ms/step - loss: 0.5882 - val_loss: 129.3449
# Epoch 9/50
# 5/5 [==============================] - 5s 952ms/step - loss: 0.5432 - val_loss: 35.5668
# Epoch 10/50
# 5/5 [==============================] - 4s 762ms/step - loss: 0.5366 - val_loss: 550.2249
# Epoch 11/50
# 5/5 [==============================] - 4s 763ms/step - loss: 0.5257 - val_loss: 468.7617
# Epoch 12/50
# 5/5 [==============================] - 4s 763ms/step - loss: 0.5242 - val_loss: 400.5186
# Epoch 13/50
# 5/5 [==============================] - 4s 762ms/step - loss: 0.5187 - val_loss: 205.8433
# Epoch 14/50
# 5/5 [==============================] - 4s 762ms/step - loss: 0.5032 - val_loss: 253.7396
# Epoch 15/50
# 5/5 [==============================] - 6s 1s/step - loss: 0.5340 - val_loss: 13.2952
# Epoch 16/50
# 5/5 [==============================] - 4s 762ms/step - loss: 0.4947 - val_loss: 64.7080
# Epoch 17/50
# 5/5 [==============================] - 5s 950ms/step - loss: 0.4903 - val_loss: 1.6462
# Epoch 18/50
# 5/5 [==============================] - 5s 970ms/step - loss: 0.4878 - val_loss: 1.1466
# Epoch 19/50
# 5/5 [==============================] - 4s 763ms/step - loss: 0.5151 - val_loss: 52.2673
# Epoch 20/50
# 5/5 [==============================] - 4s 763ms/step - loss: 0.4827 - val_loss: 39.0798
# Epoch 21/50
# 5/5 [==============================] - 4s 764ms/step - loss: 0.4908 - val_loss: 7.9891
# Epoch 22/50
# 5/5 [==============================] - 4s 762ms/step - loss: 0.4849 - val_loss: 5.2771
# Epoch 23/50
# 5/5 [==============================] - 4s 762ms/step - loss: 0.4847 - val_loss: 158.2112
# Epoch 24/50
# 5/5 [==============================] - 4s 764ms/step - loss: 0.4700 - val_loss: 5.4994
# Epoch 25/50
# 5/5 [==============================] - 4s 762ms/step - loss: 0.4790 - val_loss: 9.2153
# Epoch 26/50
# 5/5 [==============================] - 4s 762ms/step - loss: 0.4695 - val_loss: 1.5306
# Epoch 27/50
# 5/5 [==============================] - 4s 764ms/step - loss: 0.4694 - val_loss: 1.7307
# Epoch 28/50
# 5/5 [==============================] - 4s 761ms/step - loss: 0.5041 - val_loss: 1.3200
# Epoch 29/50
# 5/5 [==============================] - 4s 760ms/step - loss: 0.4680 - val_loss: 5.4127
# Epoch 30/50
# 5/5 [==============================] - 4s 763ms/step - loss: 0.4723 - val_loss: 17.8475
# Epoch 31/50
# 5/5 [==============================] - 4s 761ms/step - loss: 0.4564 - val_loss: 2.3875
# Epoch 32/50
# 5/5 [==============================] - 4s 762ms/step - loss: 0.4741 - val_loss: 5.1751
# Epoch 33/50
# 5/5 [==============================] - 4s 763ms/step - loss: 0.4678 - val_loss: 63.6490
# Epoch 34/50
# 5/5 [==============================] - 4s 762ms/step - loss: 0.4574 - val_loss: 10.1639
# Epoch 35/50
# 5/5 [==============================] - 4s 763ms/step - loss: 0.4441 - val_loss: 1.9707
# Epoch 36/50
# 5/5 [==============================] - 4s 763ms/step - loss: 0.4419 - val_loss: 9.0289
# Epoch 37/50
# 5/5 [==============================] - 4s 761ms/step - loss: 0.4527 - val_loss: 2.4530
# Epoch 38/50
# 5/5 [==============================] - 6s 1s/step - loss: 0.4336 - val_loss: 0.7821
# Epoch 39/50
# 5/5 [==============================] - 4s 762ms/step - loss: 0.4869 - val_loss: 2.4364
# Epoch 40/50
# 5/5 [==============================] - 4s 761ms/step - loss: 0.4670 - val_loss: 2.9303
# Epoch 41/50
# 5/5 [==============================] - 4s 757ms/step - loss: 0.4487 - val_loss: 3.1767
# Epoch 42/50
# 5/5 [==============================] - 4s 762ms/step - loss: 0.4400 - val_loss: 1.1359
# Epoch 43/50
# 5/5 [==============================] - 4s 763ms/step - loss: 0.4556 - val_loss: 1.2451
# Epoch 44/50
# 5/5 [==============================] - 4s 763ms/step - loss: 0.4537 - val_loss: 4.6046
# Epoch 45/50
# 5/5 [==============================] - 4s 762ms/step - loss: 0.4212 - val_loss: 3.1508
# Epoch 46/50
# 5/5 [==============================] - 4s 764ms/step - loss: 0.4249 - val_loss: 1.7971
# Epoch 47/50
# 5/5 [==============================] - 4s 763ms/step - loss: 0.4448 - val_loss: 1.5968
# Epoch 48/50
# 5/5 [==============================] - 4s 763ms/step - loss: 0.4292 - val_loss: 2.1754
# Epoch 49/50
# 5/5 [==============================] - 4s 763ms/step - loss: 0.4182 - val_loss: 1.3746
# Epoch 50/50
# 5/5 [==============================] - 4s 761ms/step - loss: 0.4402 - val_loss: 1.8217

# %%
epochs = range(1, len(history.history["loss"]) + 1)
loss = history.history["loss"]
val_loss = history.history["val_loss"]
plt.figure()
plt.plot(epochs, loss, "bo", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()

# %%
model = keras.models.load_model("/gdrive/MyDrive/Colab Notebooks/victor/unet2_trash.keras")

# %%
i=24
test_image = train_input_imgs[i]
plt.axis("off")
plt.imshow(keras.preprocessing.image.array_to_img(test_image))

# %%
mask = model.predict(np.expand_dims(test_image, 0))[0]
def display_mask(pred):
  mask = np.argmax(pred, axis=-1)
  mask *= 127
  plt.axis("off")
  plt.imshow(mask)
display_mask(mask)

# %%
test_image = train_targets[i]
plt.axis("off")
plt.imshow(keras.preprocessing.image.array_to_img(test_image))
